# %% [markdown]
# <a href="https://colab.research.google.com/github/Sairaj-97/Machine-Learning/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is DBSCAN?**
#
# -Unsupervised clustering algorithm that groups data based on density.
#
# -Detects arbitrary-shaped clusters and outliers (noise).
#
# -Does not require the number of clusters (K) to be specified.
#
# **🧠 Key Concepts**
# Term	Description
# -Core Point	Has at least min_samples points within distance eps
# -Border Point	Not a core, but within eps of a core point
# -Noise Point	Not a core or border → considered outlier (labeled -1)
#
# **🔧 Parameters**
# Parameter	Meaning
# -eps	Radius of neighborhood (distance threshold)
# -min_samples	Minimum number of points to form a dense region
#
# ⚙️ How DBSCAN Works
# Start with all points unvisited.
#
# **For each point**:
#
# -Find neighbors within eps
#
# -If ≥ min_samples, it becomes a core point
#
# -Form a cluster and expand by connecting other core points
#
# **Advantages**
#
# -Mark unclustered points as noise.
# 🚫 No need to pre-specify number of clusters (unlike K-Means)
#
# ✅ Detects noise/outliers
#
# ✅ Works with arbitrarily-shaped clusters
#
# ✅ Deterministic (no randomness)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import sklearn.datasets

# %%
iris = sklearn.datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
X=df
scaler=StandardScaler()
X=scaler.fit_transform(X)
X_df=pd.DataFrame(X,columns=iris.feature_names)
X_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444

# %%
db=DBSCAN(eps=0.5,min_samples=5)

# %%
predictions=db.fit_predict(X)
